# %% [markdown]
# Q1: What are the key limitations of traditional MapReduce that make Spark a preferred choice for modern big data processing?

# %% [markdown]
# Traditional MapReduce is slower because it stores intermediate data on disk after every step. It also requires more complex coding and is not efficient for real-time processing or iterative tasks. Spark solves these issues by using in-memory processing, which makes it much faster and easier to use for modern big data analytics.

# %% [markdown]
# Q2: Explain how Spark uses In-Memory Computing to speed up iterative machine learning algorithms compared to disk-based systems.

# %% [markdown]
# Spark uses in-memory computing, which means data is stored in RAM instead of repeatedly reading and writing from disk. In iterative machine learning algorithms, the same data is processed multiple times, so keeping it in memory makes execution much faster compared to disk-based systems like traditional MapReduce.

# %% [markdown]
# Q3: Write a code snippet to remove all duplicate rows from a DataFrame based on a specific set of columns: user_id and transaction_date.

# %% [markdown]
# ```python
# df = df.dropDuplicates(["user_id", "transaction_date"])
#
# df.show()
# ```
#
# This code removes duplicate rows based on the `user_id` and `transaction_date` columns.

# %% [markdown]
# Q4: Given a DataFrame df_sales, write a query to filter for rows where the region is 'West' and then group by product_category to find the average sale_amount.

# %% [markdown]
# ```python
# west_sales = df_sales.filter(df_sales.region == "West") \
#     .groupBy("product_category") \
#     .avg("sale_amount")
#
# west_sales.show()
# ```

# %% [markdown]
# Q5: What is the difference between .na.drop() and .na.fill()? Provide a code example of filling null values in a status column with the string 'Unknown'.

# %% [markdown]
# `.na.drop()` removes rows that contain null values, while `.na.fill()` replaces null values with a specified value.
#
# Example:
#
# ```python id="z07mbv"
# df = df.na.fill("Unknown", subset=["status"])
#
# df.show()
# ```
#
# This code replaces null values in the `status` column with `"Unknown"`.

# %% [markdown]
# Q6: Write a query to find the total count of records for each city in a DataFrame, but only for cities where the count is greater than 100.

# %% [markdown]
# ```python
# city_count = df.groupBy("city") \
#     .count() \
#     .filter("count > 100")
#
# city_count.show()
# ```

# %% [markdown]
# Q7: How does the immutability of Spark DataFrames affect how you perform "data cleaning" steps like dropping columns or renaming them?

# %% [markdown]
# Spark DataFrames are immutable, which means the original DataFrame cannot be changed directly. Operations like dropping or renaming columns create a new DataFrame instead of modifying the existing one. That is why we usually reassign the result back to a variable during data cleaning.

# %% [markdown]
# Q8: Write a Spark command to filter a dataset for rows where the age is between 18 and 30 (inclusive) and the subscription is 'Premium'.

# %% [markdown]
# ```python
# filtered_df = df.filter(
#     (df.age >= 18) &
#     (df.age <= 30) &
#     (df.subscription == "Premium")
# )
#
# filtered_df.show()
# ```

# %% [markdown]
# Q9: When cleaning a dataset, why is it often better to handle null values before performing mathematical aggregations like sum() or avg()?

# %% [markdown]
# Handling null values before using functions like `sum()` or `avg()` is important because null values can affect calculation accuracy and lead to incorrect results. Cleaning the data first ensures that aggregations are performed on valid and meaningful values only.

# %% [markdown]
# Q10: Write the code to revise a column named raw_timestamp by casting it to a TimestampType and renaming it to event_time.

# %% [markdown]
# ```python
# from pyspark.sql.types import TimestampType
# from pyspark.sql.functions import col
#
# df = df.withColumn(
#     "event_time",
#     col("raw_timestamp").cast(TimestampType())
# ).drop("raw_timestamp")
#
# df.show()
# ```

# %% [markdown]
# Q11: Explain the "Shuffle" process that occurs during a grouping operation. Why is it considered a wide transformation?

# %% [markdown]
# Shuffle is the process where Spark redistributes data across different partitions during operations like `groupBy()`. Spark moves related data to the same partition so that aggregations can be performed correctly.
#
# It is called a wide transformation because data is exchanged between partitions instead of being processed independently within the same partition. This makes the operation more expensive in terms of time and resources.

# %% [markdown]
# Q12: Write a code snippet that identifies and removes rows where the email column contains null values OR the username is an empty string.

# %% [markdown]
# ```python
# clean_df = df.filter(
#     (col("email").isNotNull()) &
#     (col("username") != "")
# )
#
# clean_df.show()
# ```
#
# This code removes rows where the `email` column is null or the `username` column is empty.

# %% [markdown]
# Q13: How do you use the .agg() function to calculate multiple statistics at once, such as the min, max, and mean of the price column?

# %% [markdown]
# ```python
# from pyspark.sql.functions import min, max, mean
#
# df.agg(
#     min("price").alias("Minimum_Price"),
#     max("price").alias("Maximum_Price"),
#     mean("price").alias("Average_Price")
# ).show()
# ```
#
# The `.agg()` function allows multiple aggregate calculations to be performed in a single query.

# %% [markdown]
# Q14: In the context of cleaning a dataset, what is the risk of using inferSchema=true when your source data contains messy or inconsistent date formats?

# %% [markdown]
# Using `inferSchema=true` with inconsistent date formats can lead to incorrect data type detection. Some date values may be interpreted as strings or null values, which can cause errors during filtering, sorting, or date-based analysis. That is why messy date columns are often cleaned and standardized before processing.
